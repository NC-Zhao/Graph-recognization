# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn import linear_model
from sklearn.model_selection import GridSearchCV
# %matplotlib inline
plt.style.use('seaborn')
from sklearn.pipeline import Pipeline

# %%
x_test = pd.read_csv('data_trouser_dress/troudress_test_x.csv')
x_train = pd.read_csv('data_trouser_dress/troudress_train_x.csv')
y_train = pd.read_csv('data_trouser_dress/troudress_train_y.csv')
x_train_r = pd.read_csv('1.csv')

# %%
# logistic
logi = linear_model.LogisticRegression()
log_p_Grid = { 'penalty':['l2','l1'], 'C': np.logspace(-3, 2, 11), 'solver':['liblinear'], 'max_iter':[200]}#tried 10 and 100,0.0001, 0.0005,  , 0.1, 1 [0.001, 0.005,0.01, 0.05, 0.1]
logiGrid = GridSearchCV(logi, log_p_Grid)
logiGrid.fit(x_train, y_train.values.reshape(-1))
logiGrid.cv_results_
# Out:
# {'mean_fit_time': array([0.56847997, 0.35385356, 0.62572489, 0.48530054, 0.67120309,
#         0.52180281, 0.90438075, 0.54274859, 0.94028444, 0.67319789,
#         1.25643845, 1.04041648, 1.44094605, 2.08978353, 1.69211226,
#         2.75183859, 1.67471938, 3.28760304, 1.67831106, 3.40549116,
#         1.8787734 , 4.02622843]),
#  'std_fit_time': array([0.02904241, 0.01058133, 0.03379474, 0.01568732, 0.02287219,
#         0.01895828, 0.04553518, 0.01451196, 0.07335775, 0.02598368,
#         0.12034191, 0.22371094, 0.07023724, 0.27769393, 0.12849581,
#         0.4961161 , 0.08218962, 0.52212213, 0.08311065, 0.4422975 ,
#         0.1957656 , 1.27176763]),
#  'mean_score_time': array([0.02214026, 0.01695533, 0.01775346, 0.01595902, 0.01775441,
#         0.019349  , 0.01855111, 0.01396375, 0.0167562 , 0.01595864,
#         0.01555924, 0.01735477, 0.01874976, 0.01815214, 0.01651568,
#         0.01795497, 0.01595864, 0.02034726, 0.01834927, 0.02014575,
#         0.01855083, 0.0189527 ]),
#  'std_score_time': array([0.00947019, 0.00063015, 0.00277778, 0.00166992, 0.00097808,
#         0.00256979, 0.00205275, 0.00178361, 0.00353262, 0.00109236,
#         0.00214786, 0.00354639, 0.00097603, 0.00213055, 0.00268431,
#         0.00141236, 0.00218503, 0.00162138, 0.0013522 , 0.00074869,
#         0.00256995, 0.00362561]),
#  'param_C': masked_array(data=[0.001, 0.001, 0.0031622776601683794,
#                     0.0031622776601683794, 0.01, 0.01, 0.03162277660168379,
#                     0.03162277660168379, 0.1, 0.1, 0.31622776601683794,
#                     0.31622776601683794, 1.0, 1.0, 3.1622776601683795,
#                     3.1622776601683795, 10.0, 10.0, 31.622776601683793,
#                     31.622776601683793, 100.0, 100.0],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_max_iter': masked_array(data=[200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200,
#                     200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_penalty': masked_array(data=['l2', 'l1', 'l2', 'l1', 'l2', 'l1', 'l2', 'l1', 'l2',
#                     'l1', 'l2', 'l1', 'l2', 'l1', 'l2', 'l1', 'l2', 'l1',
#                     'l2', 'l1', 'l2', 'l1'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_solver': masked_array(data=['liblinear', 'liblinear', 'liblinear', 'liblinear',
#                     'liblinear', 'liblinear', 'liblinear', 'liblinear',
#                     'liblinear', 'liblinear', 'liblinear', 'liblinear',
#                     'liblinear', 'liblinear', 'liblinear', 'liblinear',
#                     'liblinear', 'liblinear', 'liblinear', 'liblinear',
#                     'liblinear', 'liblinear'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'C': 0.001,
#    'max_iter': 200,
#    'penalty': 'l2',
#    'solver': 'liblinear'},
#   {'C': 0.001, 'max_iter': 200, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 0.0031622776601683794,
#    'max_iter': 200,
#    'penalty': 'l2',
#    'solver': 'liblinear'},
#   {'C': 0.0031622776601683794,
#    'max_iter': 200,
#    'penalty': 'l1',
#    'solver': 'liblinear'},
#   {'C': 0.01, 'max_iter': 200, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 0.01, 'max_iter': 200, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 0.03162277660168379,
#    'max_iter': 200,
#    'penalty': 'l2',
#    'solver': 'liblinear'},
#   {'C': 0.03162277660168379,
#    'max_iter': 200,
#    'penalty': 'l1',
#    'solver': 'liblinear'},
#   {'C': 0.1, 'max_iter': 200, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 0.1, 'max_iter': 200, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 0.31622776601683794,
#    'max_iter': 200,
#    'penalty': 'l2',
#    'solver': 'liblinear'},
#   {'C': 0.31622776601683794,
#    'max_iter': 200,
#    'penalty': 'l1',
#    'solver': 'liblinear'},
#   {'C': 1.0, 'max_iter': 200, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 1.0, 'max_iter': 200, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 3.1622776601683795,
#    'max_iter': 200,
#    'penalty': 'l2',
#    'solver': 'liblinear'},
#   {'C': 3.1622776601683795,
#    'max_iter': 200,
#    'penalty': 'l1',
#    'solver': 'liblinear'},
#   {'C': 10.0, 'max_iter': 200, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 10.0, 'max_iter': 200, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 31.622776601683793,
#    'max_iter': 200,
#    'penalty': 'l2',
#    'solver': 'liblinear'},
#   {'C': 31.622776601683793,
#    'max_iter': 200,
#    'penalty': 'l1',
#    'solver': 'liblinear'},
#   {'C': 100.0, 'max_iter': 200, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 100.0, 'max_iter': 200, 'penalty': 'l1', 'solver': 'liblinear'}],
#  'split0_test_score': array([0.94583333, 0.5       , 0.95125   , 0.90583333, 0.95416667,
#         0.93541667, 0.95      , 0.94833333, 0.94583333, 0.95541667,
#         0.93875   , 0.9475    , 0.92791667, 0.93833333, 0.9225    ,
#         0.9275    , 0.92166667, 0.9225    , 0.92166667, 0.92166667,
#         0.92166667, 0.92166667]),
#  'split1_test_score': array([0.9525    , 0.5       , 0.95333333, 0.91125   , 0.95083333,
#         0.94083333, 0.95208333, 0.95208333, 0.94666667, 0.95458333,
#         0.93916667, 0.95166667, 0.93333333, 0.93958333, 0.92791667,
#         0.93291667, 0.92708333, 0.92833333, 0.92625   , 0.92666667,
#         0.92625   , 0.92666667]),
#  'split2_test_score': array([0.95541667, 0.5       , 0.95708333, 0.92041667, 0.95541667,
#         0.94916667, 0.9525    , 0.95583333, 0.94416667, 0.95708333,
#         0.93958333, 0.94833333, 0.93666667, 0.93958333, 0.935     ,
#         0.93583333, 0.93458333, 0.93416667, 0.93416667, 0.93375   ,
#         0.93333333, 0.93375   ]),
#  'split3_test_score': array([0.95416667, 0.5       , 0.955     , 0.91416667, 0.95583333,
#         0.9475    , 0.94791667, 0.95541667, 0.94458333, 0.95583333,
#         0.93875   , 0.94625   , 0.93083333, 0.93833333, 0.92875   ,
#         0.92958333, 0.9275    , 0.92708333, 0.9275    , 0.92791667,
#         0.92666667, 0.92791667]),
#  'split4_test_score': array([0.95041667, 0.5       , 0.95291667, 0.92166667, 0.955     ,
#         0.94083333, 0.95416667, 0.95333333, 0.94916667, 0.95416667,
#         0.94416667, 0.94791667, 0.93916667, 0.94291667, 0.93791667,
#         0.93875   , 0.93791667, 0.93791667, 0.93791667, 0.93791667,
#         0.9375    , 0.93791667]),
#  'mean_test_score': array([0.95166667, 0.5       , 0.95391667, 0.91466667, 0.95425   ,
#         0.94275   , 0.95133333, 0.953     , 0.94608333, 0.95541667,
#         0.94008333, 0.94833333, 0.93358333, 0.93975   , 0.93041667,
#         0.93291667, 0.92975   , 0.93      , 0.9295    , 0.92958333,
#         0.92908333, 0.92958333]),
#  'std_test_score': array([0.00336444, 0.        , 0.00198256, 0.00586539, 0.00179505,
#         0.00499722, 0.00216346, 0.00270545, 0.00177951, 0.00102062,
#         0.00206492, 0.00180662, 0.0040104 , 0.00167912, 0.00545817,
#         0.00407397, 0.00578912, 0.00543267, 0.00580589, 0.00567034,
#         0.00561743, 0.00567034]),
#  'rank_test_score': array([ 5, 22,  3, 21,  2,  9,  6,  4,  8,  1, 10,  7, 12, 11, 14, 13, 16,
#         15, 19, 17, 20, 17])}

# %%
from sklearn.metrics import roc_curve
model = linear_model.LogisticRegression(solver = 'liblinear', max_iter = 200, penalty = 'l2', C = 0.03162277660168379)
model.fit(x_train, y_train.values.reshape(-1))
yproba1_full = model.predict_proba(x_train)[:, 1]

# %%
np.savetxt('none.txt', yproba1_full)
