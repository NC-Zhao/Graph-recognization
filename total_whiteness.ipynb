# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn import linear_model
from sklearn.model_selection import GridSearchCV
# %matplotlib inline
plt.style.use('seaborn')
from sklearn.pipeline import Pipeline

# %%
x_test = pd.read_csv('data_trouser_dress/troudress_test_x.csv')
x_train = pd.read_csv('data_trouser_dress/troudress_train_x.csv')
y_train = pd.read_csv('data_trouser_dress/troudress_train_y.csv')
x_train_r = pd.read_csv('1.csv')

# %%
x_train = x_train.append(x_train_r, ignore_index=True)

# %%
y_train = y_train.append(y_train, ignore_index=True)
# y_train

# %%
# fit on x1, transform on x2
def add_scaled_sum(x1, x2):
    def fit_sum(x):
        s = x.apply(sum, axis = 1)
    #     print(s.values)
        scaler = MinMaxScaler()
        scaler.fit(s.values.reshape(-1,1) )
        return scaler
    def transform_scale_sum(x, scaler): #transform the sums with the scaler
        s = x.apply(sum, axis = 1)
        return scaler.transform(s.values.reshape(-1,1))
    scaler = fit_sum(x1)
    x2['whiteness'] = transform_scale_sum(x2, scaler)
    return x2

# %%
x_train = add_scaled_sum(x_train, x_train)

# %%
x_test = add_scaled_sum(x_train, x_test)
# a = x_test.iloc[:, 784].values
# print(a.min())
# print(a.max())

# %%
# logistic
logi = linear_model.LogisticRegression()
log_p_Grid = { 'penalty':['l2','l1'], 'C': np.logspace(-3, -1, 7), 'solver':['liblinear'], 'max_iter':[200]}
logiGrid = GridSearchCV(logi, log_p_Grid)
logiGrid.fit(x_train, y_train.values.reshape(-1))
logiGrid.cv_results_
# Out:
# {'mean_fit_time': array([0.9024775 , 0.75334892, 1.09129415, 0.83364429, 1.09410295,
#         0.83199601, 1.18463087, 0.88478689, 1.76827116, 0.99614129,
#         1.47846794, 0.98536716, 1.56599398, 1.16908178]),
#  'std_fit_time': array([0.01104659, 0.01267038, 0.03952123, 0.05515249, 0.00781467,
#         0.01956367, 0.04230126, 0.03014446, 0.07915856, 0.08880888,
#         0.01532845, 0.00907172, 0.0291149 , 0.02259817]),
#  'mean_score_time': array([0.01714325, 0.01613712, 0.01574645, 0.01595979, 0.01533241,
#         0.01594315, 0.01855135, 0.01554432, 0.02433577, 0.01814451,
#         0.01653533, 0.01555839, 0.01634889, 0.01515937]),
#  'std_score_time': array([0.00270058, 0.00145814, 0.00098773, 0.00108759, 0.00102781,
#         0.00156514, 0.00240993, 0.0013587 , 0.00184891, 0.00353905,
#         0.00149466, 0.00048912, 0.00163061, 0.0007454 ]),
#  'param_C': masked_array(data=[0.001, 0.001, 0.0021544346900318843,
#                     0.0021544346900318843, 0.004641588833612777,
#                     0.004641588833612777, 0.01, 0.01, 0.021544346900318832,
#                     0.021544346900318832, 0.046415888336127774,
#                     0.046415888336127774, 0.1, 0.1],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_max_iter': masked_array(data=[200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200,
#                     200, 200, 200],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_penalty': masked_array(data=['l2', 'l1', 'l2', 'l1', 'l2', 'l1', 'l2', 'l1', 'l2',
#                     'l1', 'l2', 'l1', 'l2', 'l1'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_solver': masked_array(data=['liblinear', 'liblinear', 'liblinear', 'liblinear',
#                     'liblinear', 'liblinear', 'liblinear', 'liblinear',
#                     'liblinear', 'liblinear', 'liblinear', 'liblinear',
#                     'liblinear', 'liblinear'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'C': 0.001,
#    'max_iter': 200,
#    'penalty': 'l2',
#    'solver': 'liblinear'},
#   {'C': 0.001, 'max_iter': 200, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 0.0021544346900318843,
#    'max_iter': 200,
#    'penalty': 'l2',
#    'solver': 'liblinear'},
#   {'C': 0.0021544346900318843,
#    'max_iter': 200,
#    'penalty': 'l1',
#    'solver': 'liblinear'},
#   {'C': 0.004641588833612777,
#    'max_iter': 200,
#    'penalty': 'l2',
#    'solver': 'liblinear'},
#   {'C': 0.004641588833612777,
#    'max_iter': 200,
#    'penalty': 'l1',
#    'solver': 'liblinear'},
#   {'C': 0.01, 'max_iter': 200, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 0.01, 'max_iter': 200, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 0.021544346900318832,
#    'max_iter': 200,
#    'penalty': 'l2',
#    'solver': 'liblinear'},
#   {'C': 0.021544346900318832,
#    'max_iter': 200,
#    'penalty': 'l1',
#    'solver': 'liblinear'},
#   {'C': 0.046415888336127774,
#    'max_iter': 200,
#    'penalty': 'l2',
#    'solver': 'liblinear'},
#   {'C': 0.046415888336127774,
#    'max_iter': 200,
#    'penalty': 'l1',
#    'solver': 'liblinear'},
#   {'C': 0.1, 'max_iter': 200, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 0.1, 'max_iter': 200, 'penalty': 'l1', 'solver': 'liblinear'}],
#  'split0_test_score': array([0.95416667, 0.84416667, 0.95541667, 0.92104167, 0.95854167,
#         0.93770833, 0.96041667, 0.94854167, 0.96104167, 0.95416667,
#         0.96104167, 0.95854167, 0.96041667, 0.96020833]),
#  'split1_test_score': array([0.958125  , 0.86229167, 0.95916667, 0.92875   , 0.95979167,
#         0.9475    , 0.96333333, 0.95520833, 0.96208333, 0.959375  ,
#         0.96145833, 0.96      , 0.96083333, 0.96291667]),
#  'split2_test_score': array([0.95270833, 0.85208333, 0.95625   , 0.920625  , 0.95895833,
#         0.93729167, 0.96104167, 0.94833333, 0.96166667, 0.95458333,
#         0.96166667, 0.95770833, 0.961875  , 0.96      ]),
#  'split3_test_score': array([0.95770833, 0.859375  , 0.95833333, 0.92770833, 0.95875   ,
#         0.94541667, 0.96083333, 0.9525    , 0.96229167, 0.956875  ,
#         0.96354167, 0.95916667, 0.96083333, 0.96208333]),
#  'split4_test_score': array([0.95583333, 0.85520833, 0.9575    , 0.92729167, 0.95875   ,
#         0.94333333, 0.96      , 0.95291667, 0.96104167, 0.956875  ,
#         0.96083333, 0.959375  , 0.960625  , 0.95979167]),
#  'mean_test_score': array([0.95570833, 0.854625  , 0.95733333, 0.92508333, 0.95895833,
#         0.94225   , 0.961125  , 0.9515    , 0.961625  , 0.956375  ,
#         0.96170833, 0.95895833, 0.96091667, 0.961     ]),
#  'std_test_score': array([0.00206071, 0.00628518, 0.00135913, 0.00350496, 0.000437  ,
#         0.00409819, 0.0011607 , 0.00266602, 0.00051707, 0.00187546,
#         0.00096285, 0.00077951, 0.00050346, 0.00125968]),
#  'rank_test_score': array([10, 14,  8, 13,  6, 12,  3, 11,  2,  9,  1,  7,  5,  4])}

# %%
logi = linear_model.LogisticRegression()
log_p_Grid = { 'penalty':['l2','none'], 'C': np.logspace(-3, -1, 7), 'solver':['lbfgs'], 'max_iter':[200]}
logiGrid = GridSearchCV(logi, log_p_Grid)
logiGrid.fit(x_train, y_train.values.reshape(-1))
logiGrid.cv_results_
# Out:
# C:\Users\Zhaohui Zhang\.conda\envs\ml135_env_sp21\lib\site-packages\sklearn\linear_model\_logistic.py:1322: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Zhaohui Zhang\.conda\envs\ml135_env_sp21\lib\site-packages\sklearn\linear_model\_logistic.py:1322: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Zhaohui Zhang\.conda\envs\ml135_env_sp21\lib\site-packages\sklearn\linear_model\_logistic.py:1322: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Zhaohui Zhang\.conda\envs\ml135_env_sp21\lib\site-packages\sklearn\linear_model\_logistic.py:1322: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Zhaohui Zhang\.conda\envs\ml135_env_sp21\lib\site-packages\sklearn\linear_model\_logistic.py:1322: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Zhaohui Zhang\.conda\envs\ml135_env_sp21\lib\site-packages\sklearn\linear_model\_logistic.py:1322: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Zhaohui Zhang\.conda\envs\ml135_env_sp21\lib\site-packages\sklearn\linear_model\_logistic.py:1322: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Zhaohui Zhang\.conda\envs\ml135_env_sp21\lib\site-packages\sklearn\linear_model\_logistic.py:1322: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Zhaohui Zhang\.conda\envs\ml135_env_sp21\lib\site-packages\sklearn\linear_model\_logistic.py:1322: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Zhaohui Zhang\.conda\envs\ml135_env_sp21\lib\site-packages\sklearn\linear_model\_logistic.py:1322: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Zhaohui Zhang\.conda\envs\ml135_env_sp21\lib\site-packages\sklearn\linear_model\_logistic.py:1322: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Zhaohui Zhang\.conda\envs\ml135_env_sp21\lib\site-packages\sklearn\linear_model\_logistic.py:1322: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Zhaohui Zhang\.conda\envs\ml135_env_sp21\lib\site-packages\sklearn\linear_model\_logistic.py:1322: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Zhaohui Zhang\.conda\envs\ml135_env_sp21\lib\site-packages\sklearn\linear_model\_logistic.py:1322: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Zhaohui Zhang\.conda\envs\ml135_env_sp21\lib\site-packages\sklearn\linear_model\_logistic.py:1322: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Zhaohui Zhang\.conda\envs\ml135_env_sp21\lib\site-packages\sklearn\linear_model\_logistic.py:1322: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Zhaohui Zhang\.conda\envs\ml135_env_sp21\lib\site-packages\sklearn\linear_model\_logistic.py:1322: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Zhaohui Zhang\.conda\envs\ml135_env_sp21\lib\site-packages\sklearn\linear_model\_logistic.py:1322: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Zhaohui Zhang\.conda\envs\ml135_env_sp21\lib\site-packages\sklearn\linear_model\_logistic.py:1322: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Zhaohui Zhang\.conda\envs\ml135_env_sp21\lib\site-packages\sklearn\linear_model\_logistic.py:1322: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Zhaohui Zhang\.conda\envs\ml135_env_sp21\lib\site-packages\sklearn\linear_model\_logistic.py:1322: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Zhaohui Zhang\.conda\envs\ml135_env_sp21\lib\site-packages\sklearn\linear_model\_logistic.py:1322: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Zhaohui Zhang\.conda\envs\ml135_env_sp21\lib\site-packages\sklearn\linear_model\_logistic.py:1322: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Zhaohui Zhang\.conda\envs\ml135_env_sp21\lib\site-packages\sklearn\linear_model\_logistic.py:1322: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Zhaohui Zhang\.conda\envs\ml135_env_sp21\lib\site-packages\sklearn\linear_model\_logistic.py:1322: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Zhaohui Zhang\.conda\envs\ml135_env_sp21\lib\site-packages\sklearn\linear_model\_logistic.py:1322: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Zhaohui Zhang\.conda\envs\ml135_env_sp21\lib\site-packages\sklearn\linear_model\_logistic.py:1322: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Zhaohui Zhang\.conda\envs\ml135_env_sp21\lib\site-packages\sklearn\linear_model\_logistic.py:1322: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Zhaohui Zhang\.conda\envs\ml135_env_sp21\lib\site-packages\sklearn\linear_model\_logistic.py:1322: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Zhaohui Zhang\.conda\envs\ml135_env_sp21\lib\site-packages\sklearn\linear_model\_logistic.py:1322: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Zhaohui Zhang\.conda\envs\ml135_env_sp21\lib\site-packages\sklearn\linear_model\_logistic.py:1322: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Zhaohui Zhang\.conda\envs\ml135_env_sp21\lib\site-packages\sklearn\linear_model\_logistic.py:1322: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Zhaohui Zhang\.conda\envs\ml135_env_sp21\lib\site-packages\sklearn\linear_model\_logistic.py:1322: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Zhaohui Zhang\.conda\envs\ml135_env_sp21\lib\site-packages\sklearn\linear_model\_logistic.py:1322: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Zhaohui Zhang\.conda\envs\ml135_env_sp21\lib\site-packages\sklearn\linear_model\_logistic.py:1322: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# {'mean_fit_time': array([1.1347682 , 2.83881054, 1.27937946, 2.88927479, 1.27220097,
#         2.86134968, 1.65896525, 2.81427617, 1.88954844, 2.81308098,
#         2.12113538, 3.02132211, 2.84778404, 2.8767139 ]),
#  'std_fit_time': array([0.06340469, 0.27502724, 0.11636235, 0.25020694, 0.19395478,
#         0.35697673, 0.28700071, 0.30817559, 0.33386445, 0.28891223,
#         0.26869432, 0.44911655, 0.1397553 , 0.30732245]),
#  'mean_score_time': array([0.01775041, 0.01974659, 0.01795459, 0.02054839, 0.01615648,
#         0.01835189, 0.01815057, 0.01735244, 0.01855116, 0.01754999,
#         0.02013898, 0.02114229, 0.01855059, 0.02154069]),
#  'std_score_time': array([0.00159668, 0.00171574, 0.00189188, 0.00185297, 0.00074724,
#         0.00101769, 0.00171671, 0.00135301, 0.00337213, 0.00205382,
#         0.00304073, 0.00171581, 0.00272081, 0.00402562]),
#  'param_C': masked_array(data=[0.001, 0.001, 0.0021544346900318843,
#                     0.0021544346900318843, 0.004641588833612777,
#                     0.004641588833612777, 0.01, 0.01, 0.021544346900318832,
#                     0.021544346900318832, 0.046415888336127774,
#                     0.046415888336127774, 0.1, 0.1],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_max_iter': masked_array(data=[200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200,
#                     200, 200, 200],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_penalty': masked_array(data=['l2', 'none', 'l2', 'none', 'l2', 'none', 'l2', 'none',
#                     'l2', 'none', 'l2', 'none', 'l2', 'none'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_solver': masked_array(data=['lbfgs', 'lbfgs', 'lbfgs', 'lbfgs', 'lbfgs', 'lbfgs',
#                     'lbfgs', 'lbfgs', 'lbfgs', 'lbfgs', 'lbfgs', 'lbfgs',
#                     'lbfgs', 'lbfgs'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'C': 0.001, 'max_iter': 200, 'penalty': 'l2', 'solver': 'lbfgs'},
#   {'C': 0.001, 'max_iter': 200, 'penalty': 'none', 'solver': 'lbfgs'},
#   {'C': 0.0021544346900318843,
#    'max_iter': 200,
#    'penalty': 'l2',
#    'solver': 'lbfgs'},
#   {'C': 0.0021544346900318843,
#    'max_iter': 200,
#    'penalty': 'none',
#    'solver': 'lbfgs'},
#   {'C': 0.004641588833612777,
#    'max_iter': 200,
#    'penalty': 'l2',
#    'solver': 'lbfgs'},
#   {'C': 0.004641588833612777,
#    'max_iter': 200,
#    'penalty': 'none',
#    'solver': 'lbfgs'},
#   {'C': 0.01, 'max_iter': 200, 'penalty': 'l2', 'solver': 'lbfgs'},
#   {'C': 0.01, 'max_iter': 200, 'penalty': 'none', 'solver': 'lbfgs'},
#   {'C': 0.021544346900318832,
#    'max_iter': 200,
#    'penalty': 'l2',
#    'solver': 'lbfgs'},
#   {'C': 0.021544346900318832,
#    'max_iter': 200,
#    'penalty': 'none',
#    'solver': 'lbfgs'},
#   {'C': 0.046415888336127774,
#    'max_iter': 200,
#    'penalty': 'l2',
#    'solver': 'lbfgs'},
#   {'C': 0.046415888336127774,
#    'max_iter': 200,
#    'penalty': 'none',
#    'solver': 'lbfgs'},
#   {'C': 0.1, 'max_iter': 200, 'penalty': 'l2', 'solver': 'lbfgs'},
#   {'C': 0.1, 'max_iter': 200, 'penalty': 'none', 'solver': 'lbfgs'}],
#  'split0_test_score': array([0.95416667, 0.959375  , 0.95625   , 0.959375  , 0.95791667,
#         0.959375  , 0.96083333, 0.959375  , 0.96083333, 0.959375  ,
#         0.960625  , 0.959375  , 0.96      , 0.959375  ]),
#  'split1_test_score': array([0.95770833, 0.95979167, 0.959375  , 0.95979167, 0.96020833,
#         0.95979167, 0.96270833, 0.95979167, 0.96270833, 0.95979167,
#         0.96125   , 0.95979167, 0.96125   , 0.95979167]),
#  'split2_test_score': array([0.9525    , 0.958125  , 0.95645833, 0.958125  , 0.95854167,
#         0.958125  , 0.96104167, 0.958125  , 0.96145833, 0.958125  ,
#         0.96166667, 0.958125  , 0.96229167, 0.958125  ]),
#  'split3_test_score': array([0.95791667, 0.9575    , 0.95791667, 0.9575    , 0.959375  ,
#         0.9575    , 0.96083333, 0.9575    , 0.9625    , 0.9575    ,
#         0.96416667, 0.9575    , 0.961875  , 0.9575    ]),
#  'split4_test_score': array([0.95541667, 0.959375  , 0.9575    , 0.959375  , 0.95895833,
#         0.959375  , 0.96041667, 0.959375  , 0.96125   , 0.959375  ,
#         0.96083333, 0.959375  , 0.96020833, 0.959375  ]),
#  'mean_test_score': array([0.95554167, 0.95883333, 0.9575    , 0.95883333, 0.959     ,
#         0.95883333, 0.96116667, 0.95883333, 0.96175   , 0.95883333,
#         0.96170833, 0.95883333, 0.961125  , 0.95883333]),
#  'std_test_score': array([0.00207331, 0.00087003, 0.00112577, 0.00087003, 0.0007728 ,
#         0.00087003, 0.00079713, 0.00087003, 0.00072887, 0.00087003,
#         0.00128019, 0.00087003, 0.00089946, 0.00087003]),
#  'rank_test_score': array([14,  6, 13,  6,  5,  6,  3,  6,  1,  6,  2,  6,  4,  6])}
